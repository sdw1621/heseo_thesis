# %% [markdown]
# <a href="https://colab.research.google.com/github/sdw1621/heseo_thesis/blob/main/4_2_2_EDA%26preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 비정형 데이터 기말과제
#
# - 레포트에 포함되어야 할 내용
#
#  1) 분석 주제 : 분석의 목표
#
#  2) 분석 데이터 : 분석용 데이터에 대한 설명(건수와 기본통계량 포함)
#
#  3) 분석 모델 : 분석유형(회귀, 분류, 군집 등..), 분석에 사용된 알고리즘과 파라미터
#
#  4) 분석 변수 : 분석의 X변수와 Y변수
#
#  5) 분석 결과 : EDA 및 시각화 결과, 분석모델의 정확도, 분석 결과의 의미 또는 활용방안
# (워드 또는 파워포인트 형식으로 위의 각 항목별로 최소 1페이지 이상 작성)
#
# - 제출물 : 레포트, 사용된 데이터, 코드
#
# - 제출파일명 : 레포트는 "기말프로젝트_성명.ppt/hwp/doc", 데이터와 코드 이름은 자유작성
#
# - 제출기한 : 12월11일까지 제출(발표가능한 과제 수준), 최종 과제 12월 19일까지 제출
#
# - 제출방법 : 본 과제 게시물에 파일 제출(용량 초과시 이메일 제출 가능, innovt@hanmail.net)
#
# - 프로젝트 발표 : 기말고사 수업(12월12일)시간에 레포트, 데이터, 코드를 가지고 5~10분 분량으로 발표할 예정입니다.
#
# - 발표 순서 : 11번째 신동욱

# %% [markdown]
# https://wikidocs.net/94600
#
# https://github.com/NLP-kr/tensorflow-ml-nlp-tf2/blob/master/4.TEXT_CLASSIFICATION/4.2.2.EDA%26preprocessing.ipynb
#
# <h1> 네이버 영화 리뷰 데이터 감성 분석 </h1>
#
# ---
# <br>
#
# 0. **각 영화당 사용자 리뷰**를 **100개**씩 모아 만들어진 **데이터**
#
# 1. 총 **20만개 리뷰**로 구성된 데이터
#
# 2. **평점이 5점 만점**에 **1, 2, 4, 5인 리뷰**들로 구성
#
#   cf) **3점 리뷰**는 **긍부정 유무가 애매**하기 때문에 데이터 구성 시 **제외**
#
# 4. **평점 4, 5인 리뷰**들에 긍정을 의미하는 **레이블 1** 부여
#
#    **평점 1, 2인 리뷰**들에 부정을 의미하는 **레이블 0** 부여
#
# 5. **감성 분류 모델 구축**
#
# <br>
#
# ---
#
# <br>
#
# * **감성** = <u>긍정 or 부정</u>의 값을 가짐
#
# * 한글 전처리 데이터를 활용해 **리뷰가 긍정인지 부정인지 판단**
#
# <br>
#
# ---
#
# <br>
#
# 1) 분석 주제 : **한글 자연어 처리** 파이썬 라이브러리 **KoNLpy**를 사용하여 한글 텍스트 분류
#
# <br>
#
# ---
#
# <br>
#
# 2) 분석 데이터 : **데이터** 파일은 <u>총 3개</u>로 구성
#
# <br>
#
# **ratings.txt** : <u>전체 20만 개</u> 리뷰 데이터로 구성
#
# <br>
#
# **ratings_train.txt** : <u>학습 총 15만 개</u> 리뷰 데이터로 구성
#
# <br>
#
# **rating_test.txt** : <u>평가 총 5만 개</u> 리뷰 데이터로 구성
#
# <br>
#
# 2개의 파일(**ratings_train, rating_test**) 리뷰 데이터 사용
#
# <br>
#
# ---
#
# <br>
#
# 3) 분석 모델 : **합성곱 신경망(CNN)**을 활용해 네이버 영화 댓글 감정 분석 **(텍스트 분류 학습)**
#
# <br>
#
# ---
#
# <br>
#
# 4) 분석 변수 : 분석의 X변수와 Y변수
#
# 1. document : 리뷰 데이터
#
# 2. label : 긍정/부정 데이터
#
#
# <br>
#
# ---
#
# <br>
#
# 5) 사용된 데이터 : Naver sentiment movie corpus v1.0
#
# &nbsp;&nbsp;&nbsp;&nbsp;데이터 출처 : https://github.com/e9t/nsmc
#
# * 추후 실제 크롤링 데이터로 분석

# %% [markdown]
# 네이버 영화 리뷰 감정 분석
#
# : 사용자 리뷰를 각 영화당 100개씩 모아 만들어진 데이터
#
# : 감정 = 긍정 or 부정의 값을 가짐
#
# 한글 데이터 전처리 과정, 전처리 데이터를 활용해 리뷰가 긍정인지 부정인지 판단

# %% [markdown]
# ## 4.2.2. 데이터 분석 및 전처리
#
# 데이터 다운로드 경로 : https://github.com/e9t/nsmc
#
# 데이터 파일은 총 3개로 구성
#
# 1. <u>ratings.txt</u>
#
#     : **전체 리뷰**를 모아둔 **데이터**
#
#     : **전체 20만** 개의 **데이터**로 구성
#
# 2. <u>ratings_train.txt</u>
#
#     : **학습 데이터**
#
#     : **총 15만** 개 **데이터**로 구성
#
# 3. <u>rating_test.txt</u>
#
#     : **평가 데이터**
#
#     : **총 5만** 개 데이터로 구성
#
# **2개의 파일(trian, test) 데이터** 사용

# %% [markdown]
# ### 데이터 분석하기
#
# **패키지 정리**
#
# 1. numpy : 과학 계산용 라이브러리
#
# 2. pandas : 데이터 조작, 분석, 연산용(숫자 테이블, 시계열 조작) 라이브러리
#
# 3. os : Operating System, 운영 체제에서 제공되는 여러 기능을 파이썬에서 수행하는 라이브러리
#
# 4. matplotlib : 데이타를 차트나 플롯(Plot)으로 그려주는 라이브러리
#
# 5. seaborn : Matplotlib을 기반으로 다양한 색상 테마와 통계용 차트 등의 기능을 추가한 시각화 패키지
#
# 6. wordcloud : 단어의 중요도에 따라 단어의 크기나 색을 변화하여 어떤 단어가 중요한지를 보여주는 라이브러리
#
# 7. sklearn : 머신러닝 분석(선형, 회귀, 군집화 등)을 할 때 유용하게 사용할 수 있는 라이브러리

# %%
import numpy as np 
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
# %matplotlib inline

# %% [markdown]
# **원본 데이터 구글 드라이브에 저장하고 불러오기**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **각 데이터 크기 확인**

# %%
DATA_IN_PATH = '/content/drive/MyDrive/Colab Notebooks/비정형데이터/final/data/'

print(os.listdir(DATA_IN_PATH))

print()

print("파일 크기 : ")
for file in  os.listdir(DATA_IN_PATH):
    if 'txt' in file :
        print(file.ljust(30) + str(round(os.path.getsize(DATA_IN_PATH + file) / 1000000, 2)) + 'MB')
# Out:
# ['ratings_test.txt', 'ratings.txt', 'ratings_train.txt', 'NanumGothic.ttf']
#
# 파일 크기 :
# ratings_test.txt              4.89MB
# ratings.txt                   19.52MB
# ratings_train.txt             14.63MB

# %% [markdown]
# 1. 전체 데이터(ratings.txt), 19.52MB : 20만 개
#
# 2. 학습 데이터(ratings_train.txt), 14.63MB : 15만 개
#
# 3. 평가 데이터(ratings_test.txt), 4.89MB : 5만 개
#
# 비율만큼 크기를 차지
#
# 판다스 패키지를 이용해 학습 데이터를 불러와서 데이터를 확인

# %%
train_data = pd.read_csv(DATA_IN_PATH + 'ratings_train.txt', header = 0, delimiter = '\t', quoting = 3)
train_data.head()
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %% [markdown]
# 한글 영화 리뷰 데이터 : 3개의 열(column)로 구성
#
# 3개의 열
#
# 1. id : 데이터 인덱스
#
# 2. document : 리뷰 데이터
#
# 3. label : 긍정/부정 데이터
#
# 위의 데이터를 사용해 학습 데이터 분석
#
# 먼저 데이터 개수를 확인해 보자.

# %%
print('전체 학습데이터의 개수: {}'.format(len(train_data)))
# Out:
# 전체 학습데이터의 개수: 150000

# %% [markdown]
# 학습 데이터 : 총 15만 개 데이터
#
# 리뷰 길이 확인
#
# train_test의 데이터 프레임의 document 열의 apply 함수 사용해 길이 값 추출

# %%
train_length = train_data['document'].astype(str).apply(len)

# %%
train_length.head()
# Out:
# 0    19
# 1    33
# 2    17
# 3    29
# 4    61
# Name: document, dtype: int64

# %% [markdown]
# document 즉, 리뷰 열의 행 별 길이를 보면 단어의 개수가
#
# 0행 : 19 개
#
# 1행 : 33 개
#
# 2행 : 17 개
#
# 3행 : 29 개
#
# 4행 : 61 개
#
# 각 행별 길이에 대한 히스토그램을 그려보자

# %%
# 그래프에 대한 이미지 사이즈 선언
# figsize: (가로, 세로) 형태의 튜플로 입력
plt.figure(figsize=(12, 5))
# 히스토그램 선언
# bins: 히스토그램 값들에 대한 버켓 범위
# range: x축 값의 범위
# alpha: 그래프 색상 투명도
# color: 그래프 색상
# label: 그래프에 대한 라벨
plt.hist(train_length, bins=200, alpha=0.5, color= 'r', label='word')
plt.yscale('log', nonposy='clip')
# 그래프 제목
plt.title('Log-Histogram of length of review')
# 그래프 x 축 라벨
plt.xlabel('Length of review')
# 그래프 y 축 라벨
plt.ylabel('Number of review')
# Out:
# Text(0, 0.5, 'Number of review')

# %% [markdown]
# 행별 문자의 길이를 보면
#
# 매우 짧은 길이부터 140자까지 고르게 분포
#
# ---
#
# 차트 결과 분석
#
# 1. 보통 20자 이하에 많이 분포
#
# 2. 길이가 길어질수록 점점 수가 적어짐
#
# 3. 140자 부근에서 데이터의 수가 갑자기 많아짐
#
# ---
#
# 이제 실제로 여러 가지 통계값을 계산해 보자

# %%
print('리뷰 길이 최대 값: {}'.format(np.max(train_length)))
print('리뷰 길이 최소 값: {}'.format(np.min(train_length)))
print('리뷰 길이 평균 값: {:.2f}'.format(np.mean(train_length)))
print('리뷰 길이 표준편차: {:.2f}'.format(np.std(train_length)))
print('리뷰 길이 중간 값: {}'.format(np.median(train_length)))
# 사분위의 대한 경우는 0~100 스케일로 되어있음
print('리뷰 길이 제 1 사분위: {}'.format(np.percentile(train_length, 25)))
print('리뷰 길이 제 3 사분위: {}'.format(np.percentile(train_length, 75)))
# Out:
# 리뷰 길이 최대 값: 158
# 리뷰 길이 최소 값: 1
# 리뷰 길이 평균 값: 35.24
# 리뷰 길이 표준편차: 29.58
# 리뷰 길이 중간 값: 27.0
# 리뷰 길이 제 1 사분위: 16.0
# 리뷰 길이 제 3 사분위: 42.0

# %% [markdown]
# ---
#
# 1. 리뷰 길이 최대 값: 158
#
# 2. 최대 글자 수 : 140
#
# * 특수 문자 등으로 인해
#
#   좀 더 긴 데이터도 포함되어 있다.
#
# 3. 최소값 : 1
#
# 4. 평균 : 약 35자
#
# 5. 중간값 : 27자
#
# * 평균보다 좀 더 작은 값을 가지고 있다.
#
# ---

# %%
plt.figure(figsize=(12, 5))
# 박스플롯 생성
# 첫번째 파라메터: 여러 분포에 대한 데이터 리스트를 입력
# labels: 입력한 데이터에 대한 라벨
# showmeans: 평균값을 마크함

plt.boxplot(train_length,
             labels=['counts'],
             showmeans=True)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fefd0410c50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fefde2256a0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fefde1ed4a8>],
#  'means': [<matplotlib.lines.Line2D at 0x7fefde1ed160>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fefde225da0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fefd0410f60>,
#   <matplotlib.lines.Line2D at 0x7fefde225320>]}

# %% [markdown]
# **값들에 대해 박스 플롯 분석**
#
# ---
#
#
# <br>
#
# 1. 댓글 길이 긴 데이터(3Q 위의 점)가 꽤 있다
#
# 2. 중앙값은 전체 데이터에서 아래쪽에 위치
#
# 3. 데이터에서 자주 사용된 어휘 알기 = 어휘 빈도 분석
#
#
# ---
#
# <br>
#
# 1. 어휘 빈도 분석은 문자열에 대해서만 진행할 수 있기 때문에 데이터 안에 들어 있는 문자열이 아닌 데이터(Null, 특수 문자 등)는 오류가 발생할 수 있으므로 모두 제거

# %%
train_review = [review for review in train_data['document'] if type(review) is str]

# %% [markdown]
# 문자열만 남은 리뷰 데이터 워드 클라우드 적용
#
# 한글 데이터로 워드 클라우드 시각화시 깨질 수 있기 때문에 한글 폰트를 설정해야 된다.
#
# 구글 클라우드 경로에 네이버 무료 한글 폰트인 나눔고딕 폰트를 옮겨넣자

# %%
wordcloud = WordCloud(font_path = DATA_IN_PATH + 'NanumGothic.ttf').generate(' '.join(train_review))

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# 워드 클라우드 결과
#
# 영화, 너무, 진짜 등의 어휘가 가장 많이 사용되는 것을 확인할 수 있다.
#
# 이제 데이터의 긍정, 부정을 나타내는 라벨값의 비율을 확인하기

# %%
stopwords_kr = ['영화', '영화가', '영화를','영화는','영화의',
                '그리고','그래도','그냥', '이렇게', 
                '내가', '이거', '이런', '이게', '그래도']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

def displayWordCloud(data = None, backgroundcolor = 'white', width=800, height=600 ):
    wordcloud = WordCloud(font_path = DATA_IN_PATH + 'NanumGothic.ttf',
                          stopwords = stopwords_kr,
                          background_color = "black", 
                          width = width, height = height).generate(' '.join(train_review))
    plt.figure(figsize = (15 , 10))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
# 결과를 출력해 보면 불용어(STOPWORD)가 너무 많습니다.
# %time displayWordCloud(' '.join(train_review))
# Out:
# CPU times: user 12.4 s, sys: 610 ms, total: 13 s
# Wall time: 13.9 s

# %%
fig, axe = plt.subplots(ncols=1)
fig.set_size_inches(6, 3)
sns.countplot(train_data['label'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print("긍정 리뷰 개수: {}".format(train_data['label'].value_counts()[1]))
print("부정 리뷰 개수: {}".format(train_data['label'].value_counts()[0]))
# Out:
# 긍정 리뷰 개수: 74827
# 부정 리뷰 개수: 75173

# %% [markdown]
# 차트 결과
#
# 라벨값은 긍정과 부정이 거의 반반씩 잘 분포됨
#
# 실제 값을 뽑아서 확인하기

# %%
train_word_counts = train_data['document'].astype(str).apply(lambda x:len(x.split(' ')))

# %% [markdown]
# 긍정과 부정의 개수가 300개 정도 차이
#
# 거의 비슷하게 분포를 보이고 있어
#
# 데이터를 그대로 사용해도 무방하다.
#
#
# ---
#
#
#
# 이제 라벨값도 확인했으니
#
# 각 리뷰의 단어 수를 확인해 보자
#
# 우선 각 데이터를 띄어쓰기 기준으로 나눠서
#
# 그 개수를 하나의 변수로 할당하고,
#
# 그 값을 사용해 히스토그램을 그려보자

# %%
plt.figure(figsize=(15, 10))
plt.hist(train_word_counts, bins=50, facecolor='r',label='train')
plt.title('Log-Histogram of word count in review', fontsize=15)
plt.yscale('log', nonposy='clip')
plt.legend()
plt.xlabel('Number of words', fontsize=15)
plt.ylabel('Number of reviews', fontsize=15)
# Out:
# Text(0, 0.5, 'Number of reviews')

# %% [markdown]
# 길이의 경우 대부분 5개 정도에 분포됨
#
# 그 이후로는 거의 고르게 분포, 30개 이상의 데이터부터는 수가 급격하게 줄어든다.
#
# 실제 값을 뽑아서 확인해보자

# %%
print('리뷰 단어 개수 최대 값: {}'.format(np.max(train_word_counts)))
print('리뷰 단어 개수 최소 값: {}'.format(np.min(train_word_counts)))
print('리뷰 단어 개수 평균 값: {:.2f}'.format(np.mean(train_word_counts)))
print('리뷰 단어 개수 표준편차: {:.2f}'.format(np.std(train_word_counts)))
print('리뷰 단어 개수 중간 값: {}'.format(np.median(train_word_counts)))
# 사분위의 대한 경우는 0~100 스케일로 되어있음
print('리뷰 단어 개수 제 1 사분위: {}'.format(np.percentile(train_word_counts, 25)))
print('리뷰 단어 개수 제 3 사분위: {}'.format(np.percentile(train_word_counts, 75)))
# Out:
# 리뷰 단어 개수 최대 값: 41
# 리뷰 단어 개수 최소 값: 1
# 리뷰 단어 개수 평균 값: 7.58
# 리뷰 단어 개수 표준편차: 6.51
# 리뷰 단어 개수 중간 값: 6.0
# 리뷰 단어 개수 제 1 사분위: 3.0
# 리뷰 단어 개수 제 3 사분위: 9.0

# %% [markdown]
# 결과 분석
#
# 1. 평균 7 ~ 8개 정도의 단어 개수를 가짐
#
# 2. 중간값 6개 정도의 단어를 가짐
#
# 3. 모델에 적용할 최대 단어 개수를 6개가 아닌 7개로 설정해도 크게 무리는 없을 것
#
# 4. 각 데이터에 대해 특수문자 유무를 확인하자.
#
# 5. 리뷰에 자주 사용되는 특별한 특수 문자는 없으므로 일반적인 마침표와 물음표만 확인

# %%
qmarks = np.mean(train_data['document'].astype(str).apply(lambda x: '?' in x)) # 물음표가 구두점으로 쓰임
fullstop = np.mean(train_data['document'].astype(str).apply(lambda x: '.' in x)) # 마침표
                  
print('물음표가있는 질문: {:.2f}%'.format(qmarks * 100))
print('마침표가 있는 질문: {:.2f}%'.format(fullstop * 100))
# Out:
# 물음표가있는 질문: 8.25%
# 마침표가 있는 질문: 51.76%

# %% [markdown]
# **마침표의 경우 절반 정도의 데이터가 가지고 있음**
#
# 이제 모든 데이터 분석이 끝났다.
#
# 이렇게 분석한 결과를 활용해 데이터를 전처리하자.

# %% [markdown]
# ### 데이터 전처리

# %%
# !pip install konlpy

# %%
import numpy as np
import pandas as pd
import re
import json
from konlpy.tag import Okt
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from tensorflow.python.keras.preprocessing.text import Tokenizer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 전처리에 사용할 라이브러리 불러온 후 판다스 데이터 프레임 형태로 불러오기

# %%
DATA_IN_PATH = '/content/drive/MyDrive/Colab Notebooks/비정형데이터/final/data/'

train_data = pd.read_csv(DATA_IN_PATH + 'ratings_train.txt', header=0, delimiter='\t', quoting=3 )

print(train_data.head(5))
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %% [markdown]
# 한글 토크 나이징 도구인 KoNLPy를 사용하여 불러온 데이터의 일부를 확인
#
# 먼저 첫 번째 리뷰에 대해 간단하게 전처리 진행

# %%
review_text = re.sub("[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]", "", train_data['document'][0]) 
print(review_text)
# Out:
# 아 더빙 진짜 짜증나네요 목소리

# %% [markdown]
# 정규 표현식을 활용해 한글이 아닌 것들을 모두 제거

# %%
okt=Okt()
review_text = okt.morphs(review_text, stem=True)
print(review_text)
# Out:
# ['아', '더빙', '진짜', '짜증나다', '목소리']

# %% [markdown]
# KoNLPy 라이브러리의 okt객체 사용
#
# 특수 문자 모두 제거
#
# 불용어 제거를 위해 문장을 단어로 나눠지고,
#
# 형태소 분석기 사용시 어간 추출을 사용하여 어간이 추출된 단어로 나눔

# %%
stop_words = set(['은', '는', '이', '가', '하', '아', '것', '들','의', '있', '되', '수', '보', '주', '등', '한'])
clean_review = [token for token in review_text if not token in stop_words]
print(clean_review)
# Out:
# ['더빙', '진짜', '짜증나다', '목소리']

# %% [markdown]
# 형태소 분석기를 사용해 문장이 각 단어로 나눠져 있음

# %%
stop_words = set(['은', '는', '이', '가', '하', '아', '것', '들','의', '있', '되', '수', '보', '주', '등', '한'])

# %% [markdown]
# 한글 불용어가 따로 정의되어 있는 파이썬 라이브러리가 없기 때문에 직접 불용어 사전 만들기 그 사전을 통해 제거하기

# %%
def preprocessing(review, okt, remove_stopwords = False, stop_words = []):
    # 함수의 인자는 다음과 같다.
    # review : 전처리할 텍스트
    # okt : okt 객체를 반복적으로 생성하지 않고 미리 생성후 인자로 받는다.
    # remove_stopword : 불용어를 제거할지 선택 기본값은 False
    # stop_word : 불용어 사전은 사용자가 직접 입력해야함 기본값은 비어있는 리스트
    
    # 1. 한글 및 공백을 제외한 문자 모두 제거.
    review_text = re.sub("[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]", "", review)
    
    # 2. okt 객체를 활용해서 형태소 단위로 나눈다.
    word_review = okt.morphs(review_text, stem=True)
    
    if remove_stopwords:
        
        # 불용어 제거(선택적)
        word_review = [token for token in word_review if not token in stop_words]
        
   
    return word_review

# %% [markdown]
# 전체 데이터에 적용하고 재사용하기 쉽게 전처리 과정을 함수로 만들기
#
# 1. 한글을 제외한 모든 문자 제거
#
# 2. 형태소 토크나이징
#
# 3. 불용어 제거

# %%
stop_words = [ '은', '는', '이', '가', '하', '아', '것', '들','의', '있', '되', '수', '보', '주', '등', '한']
okt = Okt()
clean_train_review = []

for review in train_data['document']:
    # 비어있는 데이터에서 멈추지 않도록 string인 경우만 진행
    if type(review) == str:
        clean_train_review.append(preprocessing(review, okt, remove_stopwords = True, stop_words=stop_words))
    else:
        clean_train_review.append([])  #string이 아니면 비어있는 값 추가

clean_train_review[:4] # 앞의 4개의 데이터 확인
# Out:
# [['더빙', '진짜', '짜증나다', '목소리'],
#  ['흠', '포스터', '보고', '초딩', '영화', '줄', '오버', '연기', '조차', '가볍다', '않다'],
#  ['너', '무재', '밓었', '다그', '래서', '보다', '추천', '다'],
#  ['교도소', '이야기', '구먼', '솔직하다', '재미', '없다', '평점', '조정']]

# %% [markdown]
# okt 객체를 생성하고 불용어 사전을 정의한 후 함수를 실행
#
# 결과
#
# 해당 리뷰를 인덱스 변환이 필요
#
# 평가 데이터도 동일하게 진행하기 때문에 평가 데이터에 대해서도 똑같이 수행함
#
# 평가 데이터를 불러온 후 ㅇ진행하면 됨

# %%
test_data = pd.read_csv(DATA_IN_PATH + 'ratings_test.txt', header=0, delimiter='\t', quoting=3 )

clean_test_review = []

for review in test_data['document']:
    # 비어있는 데이터에서 멈추지 않도록 string인 경우만 진행
    if type(review) == str:
        clean_test_review.append(preprocessing(review, okt, remove_stopwords = True, stop_words=stop_words))
    else:
        clean_test_review.append([])  #string이 아니면 비어있는 값 추가

# %% [markdown]
# 학습 데이터와 평가 데이터에 대해 인덱스 벡터로 바꾼 후 패딩 처리만 하면 모든 전처리 과정이 끝난다.
#
# 텐서플로의 전처리 모듈을 사용하는데 토크나이징 객체를 만든 후
#
# 학습 데이터에 대해서만 적용하고
#
# 해당 객체를 사용해 두 데이터를 인덱스 벡터로 만들자
#
# 그 다음 마지막으로 해당 데이터들을 패딩처리하면 된다.

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(clean_train_review)
train_sequences = tokenizer.texts_to_sequences(clean_train_review)
test_sequences = tokenizer.texts_to_sequences(clean_test_review)

word_vocab = tokenizer.word_index # 단어 사전 형태
word_vocab["<PAD>"] = 0

# %%
MAX_SEQUENCE_LENGTH = 8 # 문장 최대 길이

train_inputs = pad_sequences(train_sequences, maxlen=MAX_SEQUENCE_LENGTH, padding='post') # 학습 데이터를 벡터화
train_labels = np.array(train_data['label']) # 학습 데이터의 라벨

test_inputs = pad_sequences(test_sequences, maxlen=MAX_SEQUENCE_LENGTH, padding='post') # 테스트 데이터를 벡터화
test_labels = np.array(test_data['label']) # 테스트 데이터의 라벨

# %%
DATA_IN_PATH = '/content/drive/MyDrive/Colab Notebooks/비정형데이터/final/'
TRAIN_INPUT_DATA = 'nsmc_train_input.npy'
TRAIN_LABEL_DATA = 'nsmc_train_label.npy'
TEST_INPUT_DATA = 'nsmc_test_input.npy'
TEST_LABEL_DATA = 'nsmc_test_label.npy'
DATA_CONFIGS = 'data_configs.json'

data_configs = {}

data_configs['vocab'] = word_vocab
data_configs['vocab_size'] = len(word_vocab) # vocab size 추가

import os
# 저장하는 디렉토리가 존재하지 않으면 생성
if not os.path.exists(DATA_IN_PATH):
    os.makedirs(DATA_IN_PATH)

# 전처리 된 학습 데이터를 넘파이 형태로 저장
np.save(open(DATA_IN_PATH + TRAIN_INPUT_DATA, 'wb'), train_inputs)
np.save(open(DATA_IN_PATH + TRAIN_LABEL_DATA, 'wb'), train_labels)
# 전처리 된 테스트 데이터를 넘파이 형태로 저장
np.save(open(DATA_IN_PATH + TEST_INPUT_DATA, 'wb'), test_inputs)
np.save(open(DATA_IN_PATH + TEST_LABEL_DATA, 'wb'), test_labels)

# 데이터 사전을 json 형태로 저장
json.dump(data_configs, open(DATA_IN_PATH + DATA_CONFIGS, 'w'), ensure_ascii=False)

# %% [markdown]
# 넘파이 배열은 지정한 경로(/content/drive/MyDrive/Colab Notebooks/비정형데이터/final/)에
#
# nsmc_train_input.npy, nsmc_train_label.npy로 저장된다.
#
# 이제 데이터를 활용해 감정 분석을 할 수 있는 모델을 만들자

# %% [markdown]
# ### 모델링
#
# 앞에서 전처리한 한글 데이터 파일을 활용해 감정분석을 위한 모델링을 해보자
#
# 1. 한글 데이터를 정제
#
# 2. 각 단어들을 벡터화
#
# 3. 넘파일 파일로 저장
#
# 4. 문제 해결 모델 적용
#
#
# 실습 모델링(합성곱 신경망)
#
# 딥러닝 방식 중 합성곱 신경망(CNN)을 활용해 문장 분류
#
# 입력값 : 앞에서 전처리한 한글 넘파이 데이터 활용

# %% [markdown]
# 학습 데이터 불러오기
#
# 모델링 과정에서 사용할 라이브러리를 모두 임포트

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import layers

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import os
import json

from tqdm import tqdm

# %% [markdown]
# 전처리한 데이터 불러오기

# %%
DATA_IN_PATH = '/content/drive/MyDrive/Colab Notebooks/비정형데이터/final/'
DATA_OUT_PATH = 'nsmc_train_input.npy'
INPUT_TRAIN_DATA = 'nsmc_train_label.npy'
LABEL_TRAIN_DATA = 'nsmc_train_label.npy'
DATA_CONFIGS = 'data_configs.json'

train_input = np.load(open(DATA_IN_PATH + INPUT_TRAIN_DATA, 'rb'))
train_input = pad_sequences(train_input, maxlen = train_input.shape[1])
train_label = np.load(open(DATA_IN_PATH + LABEL_TRAIN_DATA, 'rb'))
prepro_configs = json.load(open(DATA_IN_PATH + DATA_CONFIGS, 'r'))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-103-a3ff1260265c> in <module>()
#       6
#       7 train_input = np.load(open(DATA_IN_PATH + INPUT_TRAIN_DATA, 'rb'))
# ----> 8 train_input = pad_sequences(train_input, maxlen = train_input.shape[1])
#       9 train_label = np.load(open(DATA_IN_PATH + LABEL_TRAIN_DATA, 'rb'))
#      10 prepro_configs = json.load(open(DATA_IN_PATH + DATA_CONFIGS, 'r'))
#
# IndexError: tuple index out of range

# %%
model_name = 'cnn_classifier_kr'
BATCH_SIZE = 512
NUM_EPOCHS = 2
VALID_SPLIT = 0.1
MAX_LEN = train_input.shape[1]

kargs = {'model_name' : model_name,
         'vocab_size':prepro_configs['vocab_size'],
         'embedding_size':128,
         'num_filters':100,
         'dropout_rate':0.5,
         'hidden_dimension':250,
         'output_dimension':1}

# %% [markdown]
# 모델에 필요한 하이퍼파라미터 값으로 에폭 수, 배치 크기, 단어 사전의 크기, 임베딩 크기 등을 지정한다. 에폭 수는 10으로 설정해서 전체 데이터를 총 2번 돌면 학습이 끝나게 한다. 그리고 단어 사전의 크기는 데이터 정보를 담은 딕셔너리에서 받아오고, 임베딕 크기는 128로 설정했다.
#
# 이제 모델을 제외한 모든 준비가 끝났으므로 모델을 구현해보자

# %% [markdown]
# 모델 함수
#
# 모델 함수 : 합성곱 신경망 모델
#
# 성능(딥러닝) 보다는 한글 데이터 처리에 중점으로 코드를 구성

# %%
class CNNClassifier(tf.keras.Model):

  def __init__(self, **kargs):
    super(CNNClassifier, self).__init__(name = kargs['model_name'])
    
    self.embedding = layers.Embedding(input_dim = kargs['vocab_size'],
                                      output_dim = kargs['embedding_size'])
    
    self.conv_list = [layers.Conv1D(filters=kargs['num_filters'],
                                    kernle_size = kernel_size,
                                    padding = 'valid',
                                    activation = tf.keras.activations.relu,
                                    
                                    kernel_constraint = tf.keras.constraints.MaxNorm(max_value=3.))
                                    for kernel_size in [3,4,5]]
                                    
    self.pooling = layers.GlobalMaxPool1D()
    self.dropout = layers.Dropout(kargs['dropout_rate'])
    self.fc1 = layers.Dense(units = kargs['hidden_dimension'],
                            activation = tf.keras.activations.relu,
                            kernel_constraint = tf.keras.constraints.MaxNorm(max_value=3.))
    self.fc2 = layers.Dense(units = kargs['hidden_dimension'],
                            activation = tf.keras.activations.relu,
                            kernel_constraint = tf.keras.constraints.MaxNorm(max_value=3.))
      
  def call(self, x) :
    x = self.embedding(x)
    x = self.dropout(x)
    x = tf.concat([self.pooling(conv(x)) for conv in self.conv_list], axis = -1)
    x = self.fc1(x)
    x = self.fc2(x)

    return x

# %% [markdown]
# 모델 학습

# %%
model = CNNClassifier(**kargs)

model.compile(optimizer = tf.keras.optimizers.Adam(),
              loss = tf.keras.losses.BinaryCrossentropy(),
              metrics = [tf.keras.metrics.BinaryAccuracy(name = 'accuracy')])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-0471290a7209> in <module>()
# ----> 1 model = CNNClassifier(**kargs)
#       2
#       3 model.compile(optimizer = tf.keras.optimizers.Adam(),
#       4               loss = tf.keras.losses.BinaryCrossentropy(),
#       5               metrics = [tf.keras.metrics.BinaryAccuracy(name = 'accuracy')])
#
# NameError: name 'kargs' is not defined
